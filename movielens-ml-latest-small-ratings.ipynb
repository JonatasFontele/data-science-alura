# %% [markdown]
# # Ratings

# %%
import pandas as pd

notas = pd.read_csv("ratings.csv")
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
notas.shape
# Out:
# (100836, 4)

# %%
# Mudando o nome das colunas
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
# Pegando valores únicos de nota
notas['nota'].unique()
# Out:
# array([4. , 5. , 3. , 2. , 1. , 4.5, 3.5, 2.5, 0.5, 1.5])

# %%
# Contando todas as notas e imprimindo em ordem decrescente de quantidade
notas['nota'].value_counts()
# Out:
# 4.0    26818
# 3.0    20047
# 5.0    13211
# 3.5    13136
# 4.5     8551
# 2.0     7551
# 2.5     5550
# 1.0     2811
# 1.5     1791
# 0.5     1370
# Name: nota, dtype: int64

# %%
# Imprimindo média e mediana 
print("Media", notas.nota.mean())
print("Mediana", notas.nota.median())
# Out:
# Media 3.501556983616962
# Mediana 3.5

# %%
# Imprimindo usando dataframe
notas['nota'].mean()
# Out:
# 3.501556983616962

# %%
# Usando pontos em vez de colchetes
notas.nota.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.0
# 3    5.0
# 4    5.0
# Name: nota, dtype: float64

# %%
# histograma
notas.nota.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
notas.nota.describe()
# Out:
# count    100836.000000
# mean          3.501557
# std           1.042529
# min           0.500000
# 25%           3.000000
# 50%           3.500000
# 75%           4.000000
# max           5.000000
# Name: nota, dtype: float64

# %%
import seaborn as sns

sns.boxplot(notas.nota)
# Out:
# C:\Users\jonat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='nota'>

# %% [markdown]
# # Movies

# %%
filmes = pd.read_csv("movies.csv")
filmes.columns = ["filmeId", "titulo", "generos"]
filmes.head()
# Out:
#    filmeId                              titulo  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                        generos
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# Notas cujo id seja 1
notas.query("filmeId==1")
# Out:
#        usuarioId  filmeId  nota     momento
# 0              1        1   4.0   964982703
# 516            5        1   4.0   847434962
# 874            7        1   4.5  1106635946
# 1434          15        1   2.5  1510577970
# 1667          17        1   4.5  1305696483
# ...          ...      ...   ...         ...
# 97364        606        1   2.5  1349082950
# 98479        607        1   4.0   964744033
# 98666        608        1   2.5  1117408267
# 99497        609        1   3.0   847221025
# 99534        610        1   5.0  1479542900
#
# [215 rows x 4 columns]

# %%
# Média da série "nota" do filme Toy Story
notas.query("filmeId==1").nota.mean()
# Out:
# 3.9209302325581397

# %%
# Automatizar médias de todos os filmes usando groupby
# Retorno será um objeto do tipo DataFrameGroupBy
# Na documentação do Pandas, há exemplos de operações que podem ser feitas a partir desse objeto
medias_por_filme = notas.groupby("filmeId").mean().nota
medias_por_filme.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
medias_por_filme.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.boxplot(y=medias_por_filme)
# Out:
# <AxesSubplot:ylabel='nota'>

# %%
medias_por_filme.describe()
# Out:
# count    9724.000000
# mean        3.262448
# std         0.869874
# min         0.500000
# 25%         2.800000
# 50%         3.416667
# 75%         3.911765
# max         5.000000
# Name: nota, dtype: float64

# %%
sns.distplot(medias_por_filme, bins=10)
# Out:
# C:\Users\jonat\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='nota', ylabel='Density'>

# %%
# Bibliotecas utilizam matplotlib, é o mais baixo nível
import matplotlib.pyplot as plt
plt.hist(medias_por_filme)
plt.title("Histograma das médias dos filmes")
# Out:
# Text(0.5, 1.0, 'Histograma das médias dos filmes')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5,8))
sns.boxplot(y=medias_por_filme)
# Out:
# <AxesSubplot:ylabel='nota'>
